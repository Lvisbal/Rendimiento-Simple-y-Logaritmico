# %% [markdown]
# <a href="https://colab.research.google.com/github/Lvisbal/Rendimiento-Simple-y-Logaritmico/blob/main/S%26P_Latam40_COVID19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Impacto del COVID19 en las características estructurales y de conexión de los componentes del índice S&P Latam40 del mercado bursátil Latinoamericano.**

# %% [markdown]
# ![covid finance.png](data:image/png;base64,...)

# %%
#Importar Librerias
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Definir rangos de fechas
start1 = '2019-03-01'
end1 = '2020-02-28'
start2 = '2020-03-01'
end2 = '2021-02-28'
start3 = '2021-03-01'
end3 = '2022-02-28'

# %%
#Vectorizar tickets (Nemotecnicos de empresas)
tickets = ['ABEV','AMXL.MX','B3SA3.SA','BBD','BSAC','CHILE.SN','BBAS3.SA','CIB','BRFS','CCRO3.SA',
           'CEMEXCPO.MX','CENCOSHOPP.SN','BAP','EC','CMPC.SN','COPEC.SN','ENELAM.SN','FEMSAUBD.MX','FUNO11.MX','GGB',
           'GFNORTEO.MX','GMEXICOB.MX','TLEVISACPO.MX','ISA.CL','ITUB','ITSA4.SA','RENT3.SA','LREN3.SA','MGLU3.SA','NTCO3.SA',
           'PAGS','PBR','RDOR3.SA','FALABELLA.SN','SQM','SCCO','STNE','VALE','WMT.MX','WEGE3.SA']

# %%
#Vectorizar tickets (Nemotecnicos de empresas)
PriceAdj1 = yf.download(tickets, start=start1, end=end1)['Adj Close']
PriceAdj2 = yf.download(tickets, start=start2, end=end2)['Adj Close']
PriceAdj3 = yf.download(tickets, start=start3, end=end3)['Adj Close']
# Out:
# [*********************100%***********************]  40 of 40 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['AMXL.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:['RDOR3.SA']: Exception("%ticker%: Data doesn't exist for startDate = 1551409200, endDate = 1582858800")
# [*********************100%***********************]  40 of 40 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMXL.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%***********************]  40 of 40 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMXL.MX']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# **Identificar Data Missing**

# %%
#Identificar datos faltantes en PriceAdj1
print("Hay {} datos".format(len(PriceAdj1)))

for i in PriceAdj1.columns:
    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(PriceAdj1[PriceAdj1[i].isna()]), np.round(len(PriceAdj1[PriceAdj1[i].isna()])/len(PriceAdj1)*100,2), i))
# Out:
# Hay 260 datos
# Hay 9 (3.46%) datos faltantes en la columna ABEV
# Hay 260 (100.0%) datos faltantes en la columna AMXL.MX
# Hay 14 (5.38%) datos faltantes en la columna B3SA3.SA
# Hay 9 (3.46%) datos faltantes en la columna BAP
# Hay 14 (5.38%) datos faltantes en la columna BBAS3.SA
# Hay 9 (3.46%) datos faltantes en la columna BBD
# Hay 9 (3.46%) datos faltantes en la columna BRFS
# Hay 9 (3.46%) datos faltantes en la columna BSAC
# Hay 14 (5.38%) datos faltantes en la columna CCRO3.SA
# Hay 10 (3.85%) datos faltantes en la columna CEMEXCPO.MX
# Hay 95 (36.54%) datos faltantes en la columna CENCOSHOPP.SN
# Hay 13 (5.0%) datos faltantes en la columna CHILE.SN
# Hay 9 (3.46%) datos faltantes en la columna CIB
# Hay 13 (5.0%) datos faltantes en la columna CMPC.SN
# Hay 13 (5.0%) datos faltantes en la columna COPEC.SN
# Hay 9 (3.46%) datos faltantes en la columna EC
# Hay 13 (5.0%) datos faltantes en la columna ENELAM.SN
# Hay 13 (5.0%) datos faltantes en la columna FALABELLA.SN
# Hay 10 (3.85%) datos faltantes en la columna FEMSAUBD.MX
# Hay 10 (3.85%) datos faltantes en la columna FUNO11.MX
# Hay 10 (3.85%) datos faltantes en la columna GFNORTEO.MX
# Hay 9 (3.46%) datos faltantes en la columna GGB
# Hay 10 (3.85%) datos faltantes en la columna GMEXICOB.MX
# Hay 1 (0.38%) datos faltantes en la columna ISA.CL
# Hay 14 (5.38%) datos faltantes en la columna ITSA4.SA
# Hay 9 (3.46%) datos faltantes en la columna ITUB
# Hay 14 (5.38%) datos faltantes en la columna LREN3.SA
# Hay 14 (5.38%) datos faltantes en la columna MGLU3.SA
# Hay 214 (82.31%) datos faltantes en la columna NTCO3.SA
# Hay 9 (3.46%) datos faltantes en la columna PAGS
# Hay 9 (3.46%) datos faltantes en la columna PBR
# Hay 260 (100.0%) datos faltantes en la columna RDOR3.SA
# Hay 14 (5.38%) datos faltantes en la columna RENT3.SA
# Hay 9 (3.46%) datos faltantes en la columna SCCO
# Hay 9 (3.46%) datos faltantes en la columna SQM
# Hay 9 (3.46%) datos faltantes en la columna STNE
# Hay 10 (3.85%) datos faltantes en la columna TLEVISACPO.MX
# Hay 9 (3.46%) datos faltantes en la columna VALE
# Hay 14 (5.38%) datos faltantes en la columna WEGE3.SA
# Hay 10 (3.85%) datos faltantes en la columna WMT.MX

# %%
#Identificar datos faltantes en PriceAdj2
print("Hay {} datos".format(len(PriceAdj2)))

for i in PriceAdj2.columns:
    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(PriceAdj2[PriceAdj2[i].isna()]), np.round(len(PriceAdj2[PriceAdj2[i].isna()])/len(PriceAdj2)*100,2), i))
# Out:
# Hay 260 datos
# Hay 9 (3.46%) datos faltantes en la columna ABEV
# Hay 260 (100.0%) datos faltantes en la columna AMXL.MX
# Hay 15 (5.77%) datos faltantes en la columna B3SA3.SA
# Hay 9 (3.46%) datos faltantes en la columna BAP
# Hay 15 (5.77%) datos faltantes en la columna BBAS3.SA
# Hay 9 (3.46%) datos faltantes en la columna BBD
# Hay 9 (3.46%) datos faltantes en la columna BRFS
# Hay 9 (3.46%) datos faltantes en la columna BSAC
# Hay 15 (5.77%) datos faltantes en la columna CCRO3.SA
# Hay 10 (3.85%) datos faltantes en la columna CEMEXCPO.MX
# Hay 11 (4.23%) datos faltantes en la columna CENCOSHOPP.SN
# Hay 11 (4.23%) datos faltantes en la columna CHILE.SN
# Hay 9 (3.46%) datos faltantes en la columna CIB
# Hay 11 (4.23%) datos faltantes en la columna CMPC.SN
# Hay 11 (4.23%) datos faltantes en la columna COPEC.SN
# Hay 9 (3.46%) datos faltantes en la columna EC
# Hay 11 (4.23%) datos faltantes en la columna ENELAM.SN
# Hay 11 (4.23%) datos faltantes en la columna FALABELLA.SN
# Hay 10 (3.85%) datos faltantes en la columna FEMSAUBD.MX
# Hay 10 (3.85%) datos faltantes en la columna FUNO11.MX
# Hay 10 (3.85%) datos faltantes en la columna GFNORTEO.MX
# Hay 9 (3.46%) datos faltantes en la columna GGB
# Hay 10 (3.85%) datos faltantes en la columna GMEXICOB.MX
# Hay 0 (0.0%) datos faltantes en la columna ISA.CL
# Hay 15 (5.77%) datos faltantes en la columna ITSA4.SA
# Hay 9 (3.46%) datos faltantes en la columna ITUB
# Hay 15 (5.77%) datos faltantes en la columna LREN3.SA
# Hay 15 (5.77%) datos faltantes en la columna MGLU3.SA
# Hay 15 (5.77%) datos faltantes en la columna NTCO3.SA
# Hay 9 (3.46%) datos faltantes en la columna PAGS
# Hay 9 (3.46%) datos faltantes en la columna PBR
# Hay 213 (81.92%) datos faltantes en la columna RDOR3.SA
# Hay 15 (5.77%) datos faltantes en la columna RENT3.SA
# Hay 9 (3.46%) datos faltantes en la columna SCCO
# Hay 9 (3.46%) datos faltantes en la columna SQM
# Hay 9 (3.46%) datos faltantes en la columna STNE
# Hay 10 (3.85%) datos faltantes en la columna TLEVISACPO.MX
# Hay 9 (3.46%) datos faltantes en la columna VALE
# Hay 15 (5.77%) datos faltantes en la columna WEGE3.SA
# Hay 10 (3.85%) datos faltantes en la columna WMT.MX

# %%
#Identificar datos faltantes en PriceAdj3
print("Hay {} datos".format(len(PriceAdj3)))
for i in PriceAdj3.columns:

    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(PriceAdj3[PriceAdj3[i].isna()]), np.round(len(PriceAdj3[PriceAdj3[i].isna()])/len(PriceAdj3)*100,2), i))
# Out:
# Hay 260 datos
# Hay 8 (3.08%) datos faltantes en la columna ABEV
# Hay 260 (100.0%) datos faltantes en la columna AMXL.MX
# Hay 10 (3.85%) datos faltantes en la columna B3SA3.SA
# Hay 8 (3.08%) datos faltantes en la columna BAP
# Hay 10 (3.85%) datos faltantes en la columna BBAS3.SA
# Hay 8 (3.08%) datos faltantes en la columna BBD
# Hay 8 (3.08%) datos faltantes en la columna BRFS
# Hay 8 (3.08%) datos faltantes en la columna BSAC
# Hay 10 (3.85%) datos faltantes en la columna CCRO3.SA
# Hay 7 (2.69%) datos faltantes en la columna CEMEXCPO.MX
# Hay 10 (3.85%) datos faltantes en la columna CENCOSHOPP.SN
# Hay 10 (3.85%) datos faltantes en la columna CHILE.SN
# Hay 8 (3.08%) datos faltantes en la columna CIB
# Hay 10 (3.85%) datos faltantes en la columna CMPC.SN
# Hay 10 (3.85%) datos faltantes en la columna COPEC.SN
# Hay 8 (3.08%) datos faltantes en la columna EC
# Hay 10 (3.85%) datos faltantes en la columna ENELAM.SN
# Hay 10 (3.85%) datos faltantes en la columna FALABELLA.SN
# Hay 7 (2.69%) datos faltantes en la columna FEMSAUBD.MX
# Hay 7 (2.69%) datos faltantes en la columna FUNO11.MX
# Hay 7 (2.69%) datos faltantes en la columna GFNORTEO.MX
# Hay 8 (3.08%) datos faltantes en la columna GGB
# Hay 7 (2.69%) datos faltantes en la columna GMEXICOB.MX
# Hay 1 (0.38%) datos faltantes en la columna ISA.CL
# Hay 10 (3.85%) datos faltantes en la columna ITSA4.SA
# Hay 8 (3.08%) datos faltantes en la columna ITUB
# Hay 10 (3.85%) datos faltantes en la columna LREN3.SA
# Hay 10 (3.85%) datos faltantes en la columna MGLU3.SA
# Hay 10 (3.85%) datos faltantes en la columna NTCO3.SA
# Hay 8 (3.08%) datos faltantes en la columna PAGS
# Hay 8 (3.08%) datos faltantes en la columna PBR
# Hay 10 (3.85%) datos faltantes en la columna RDOR3.SA
# Hay 10 (3.85%) datos faltantes en la columna RENT3.SA
# Hay 8 (3.08%) datos faltantes en la columna SCCO
# Hay 8 (3.08%) datos faltantes en la columna SQM
# Hay 8 (3.08%) datos faltantes en la columna STNE
# Hay 7 (2.69%) datos faltantes en la columna TLEVISACPO.MX
# Hay 8 (3.08%) datos faltantes en la columna VALE
# Hay 10 (3.85%) datos faltantes en la columna WEGE3.SA
# Hay 7 (2.69%) datos faltantes en la columna WMT.MX

# %%
#Excluyendo tickets en PriceAdj1
data1 = PriceAdj1.drop(['CENCOSHOPP.SN', 'NTCO3.SA', 'RDOR3.SA', 'AMXL.MX' ], axis=1)
data2 = PriceAdj2.drop(['CENCOSHOPP.SN', 'NTCO3.SA', 'RDOR3.SA', 'AMXL.MX'], axis=1)
data3 = PriceAdj3.drop(['CENCOSHOPP.SN', 'NTCO3.SA', 'RDOR3.SA', 'AMXL.MX'], axis=1)

# %%
data1
# Out:
#                 ABEV   B3SA3.SA         BAP   BBAS3.SA       BBD  BRFS  \
# Date
# 2019-03-01  3.786202   8.922681  237.193878  38.584709  7.560734  5.46
# 2019-03-04  3.777578        NaN  239.664017        NaN  7.554000  5.42
# 2019-03-05  3.777578        NaN  236.033188        NaN  7.621325  5.31
# 2019-03-06  3.648208   8.847114  238.681915  38.073353  7.395686  5.17
# 2019-03-07  3.674083   8.701571  234.366592  38.364208  7.368741  5.05
# ...              ...        ...         ...        ...       ...   ...
# 2020-02-21  3.246213  14.995778  197.631805  38.992496  6.213054  6.92
# 2020-02-24  3.166606        NaN  192.374054        NaN  6.007095  6.70
# 2020-02-25  3.193141        NaN  186.352448        NaN  5.904116  6.57
# 2020-02-26  3.157760  13.814554  187.870255  36.153954  5.826883  6.39
# 2020-02-27  2.874712  13.264279  181.352615  36.601589  5.766811  6.18
#
#                  BSAC   CCRO3.SA  CEMEXCPO.MX   CHILE.SN  ...       PAGS  \
# Date                                                      ...
# 2019-03-01  24.299585  12.204789     9.201652  77.633278  ...  27.969999
# 2019-03-04  24.609432        NaN     9.104178  78.077927  ...  28.389999
# 2019-03-05  24.439014        NaN     8.938470  76.879631  ...  28.530001
# 2019-03-06  24.353807  12.012313     8.948218  77.475014  ...  27.600000
# 2019-03-07  23.920025  11.111170     8.860490  77.912132  ...  26.969999
# ...               ...        ...          ...        ...  ...        ...
# 2020-02-21  15.469760  16.709518     7.100000  60.187401  ...  36.580002
# 2020-02-24  14.777926        NaN     7.050000  59.360455  ...  34.680000
# 2020-02-25  14.568767        NaN     6.900000  59.446270  ...  34.029999
# 2020-02-26  14.761837  15.310153     6.440000  60.000172  ...  34.570000
# 2020-02-27  14.617034  14.582852     6.170000  60.093784  ...  32.740002
#
#                  PBR   RENT3.SA       SCCO        SQM       STNE  \
# Date
# 2019-03-01  6.499362  30.107754  29.100334  31.018496  31.129999
# 2019-03-04  6.528733        NaN  29.067787  30.750355  32.000000
# 2019-03-05  6.570692        NaN  29.490831  31.042154  32.189999
# 2019-03-06  6.415446  30.242167  29.393209  30.387560  31.000000
# 2019-03-07  6.310550  29.677647  29.100334  29.685640  29.030001
# ...              ...        ...        ...        ...        ...
# 2020-02-21  5.944923  51.704613  31.857040  26.204451  43.480000
# 2020-02-24  5.542380        NaN  30.417793  25.126652  41.779999
# 2020-02-25  5.432210        NaN  29.500380  24.484911  41.000000
# 2020-02-26  5.317804  48.121414  29.483540  23.974806  41.570000
# 2020-02-27  5.118651  46.904835  28.254711  22.773598  41.849998
#
#             TLEVISACPO.MX      VALE   WEGE3.SA       WMT.MX
# Date
# 2019-03-01      42.190563  9.106669   8.662211  1883.326050
# 2019-03-04      41.636929  9.128717        NaN  1853.587524
# 2019-03-05      40.367393  9.305119        NaN  1853.587524
# 2019-03-06      38.754227  9.180167   8.775565  1877.965820
# 2019-03-07      38.582409  9.261018   8.747227  1902.872925
# ...                   ...       ...        ...          ...
# 2020-02-21      41.498325  8.615326  23.785786  2231.953369
# 2020-02-24      41.199501  7.966536        NaN  2212.007080
# 2020-02-25      38.481140  7.777935        NaN  2190.565430
# 2020-02-26      38.182316  7.679861  22.442839  2180.193359
# 2020-02-27      36.900249  7.483716  21.072210  2150.174561
#
# [260 rows x 36 columns]

# %%
#Separando la variable date de la serie
#dates1 = data1.index
#dates2 = data2.index
#dates3 = data3.index

# %%
# Separar el resto de la serie de tiempo a un DataFrame para imputar los valores faltantes
#values = data1.pop(Tickets)

# %% [markdown]
# **Imputando Data Missing**
# **#Metodo: KNN (K-NEAREST NEIGHBOR)**

# %%
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error

# %%
#Imputando data missing (KNN) en data1
# define imputer
imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
# fit on the dataset
imputer.fit(data1)
# transform the dataset
dat1 = imputer.transform(data1)
imputed_data1=round(pd.DataFrame(dat1,columns=data1.columns),2)
imputed_data1
# Out:
#      ABEV  B3SA3.SA     BAP  BBAS3.SA   BBD  BRFS   BSAC  CCRO3.SA  \
# 0    3.79      8.92  237.19     38.58  7.56  5.46  24.30     12.20
# 1    3.78      8.91  239.66     39.13  7.55  5.42  24.61     11.56
# 2    3.78      8.91  236.03     39.13  7.62  5.31  24.44     11.56
# 3    3.65      8.85  238.68     38.07  7.40  5.17  24.35     12.01
# 4    3.67      8.70  234.37     38.36  7.37  5.05  23.92     11.11
# ..    ...       ...     ...       ...   ...   ...    ...       ...
# 255  3.25     15.00  197.63     38.99  6.21  6.92  15.47     16.71
# 256  3.17     13.53  192.37     38.74  6.01  6.70  14.78     15.74
# 257  3.19     13.19  186.35     37.60  5.90  6.57  14.57     14.93
# 258  3.16     13.81  187.87     36.15  5.83  6.39  14.76     15.31
# 259  2.87     13.26  181.35     36.60  5.77  6.18  14.62     14.58
#
# ..           ...       ...  ...    ...   ...       ...    ...    ...    ...
# 255        13.09     65.74  ...  58.35  3.40     58.50  71.68  49.09  87.56
# 256        13.29     64.06  ...  58.05  3.62     58.70  69.70  48.02  88.19
# 257        14.01     65.12  ...  57.94  3.73     57.97  69.00  49.05  87.99
# 258        13.66     64.88  ...  55.30  3.54     57.32  66.01  46.40  84.45
# 259        13.94     65.12  ...  58.06  3.39     55.54  62.72  45.36  85.81
#
#      TLEVISACPO.MX   VALE  WEGE3.SA   WMT.MX
# 0            34.80   7.75     22.52  2248.91
# 1            34.50   7.71     22.97  2183.09
# 2            36.19   7.97     23.22  2263.87
# 3            34.46   7.63     22.38  2275.83
# 4            33.00   7.19     21.10  2342.98
# ..             ...    ...       ...      ...
# 255          31.02  13.79     39.83  2854.54
# 256          30.74  14.08     40.28  2781.06
# 257          31.13  14.20     41.74  2711.59
# 258          29.71  13.69     38.52  2744.33
# 259          30.01  13.30     37.58  2723.26
#
# [260 rows x 36 columns]

# %%
#Imputando data missing (KNN) en data3
from sklearn.impute import KNNImputer
# define imputer
imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
# fit on the dataset
imputer.fit(data3)
# transform the dataset
dat3 = imputer.transform(data3)
imputed_data3=round(pd.DataFrame(dat3,columns=data3.columns),2)
imputed_data3
# Out:
#      ABEV  B3SA3.SA     BAP  BBAS3.SA   BBD  BRFS   BSAC  CCRO3.SA  \
# 0    2.28     16.19  157.49     23.31  3.50  3.89  19.89     10.44
# 1    2.30     16.69  157.67     24.21  3.58  3.88  20.18     10.40
# 2    2.33     16.86  157.06     24.26  3.60  3.89  20.66     10.55
# 3    2.43     16.53  154.78     25.14  3.72  4.04  20.57     11.12
# 4    2.47     16.83  154.27     25.61  3.88  4.19  20.70     11.23
# ..    ...       ...     ...       ...   ...   ...    ...       ...
# 255  2.69     13.33  147.29     31.32  3.67  3.78  16.87     12.23
# 256  2.74     13.63  150.35     31.62  3.77  3.74  16.95     12.45
# 257  2.81     13.82  148.93     31.78  3.81  3.71  16.88     12.26
# 258  2.73     13.92  144.03     30.77  3.60  3.40  16.37     12.03
# 259  2.81     13.81  149.78     31.26  3.60  3.27  16.81     11.40
#
#      CEMEXCPO.MX  CHILE.SN  ...   PAGS   PBR  RENT3.SA   SCCO    SQM   STNE  \
# 0          14.07     66.30  ...  61.69  3.34     56.65  65.85  46.40  89.67
# 1          14.37     67.71  ...  60.11  3.31     56.12  66.94  47.45  87.77
# 2          15.18     70.21  ...  55.64  3.18     56.33  67.69  46.09  82.31
# 3          14.34     69.31  ...  52.63  3.26     58.34  62.78  42.70  77.25
# 4          14.63     70.21  ...  53.10  3.32     58.25  64.83  43.19  76.67
# ..           ...       ...  ...    ...   ...       ...    ...    ...    ...
# 255        11.34     71.14  ...  17.11  7.13     56.01  61.42  51.56  11.89
# 256        11.28     70.71  ...  15.26  7.54     59.42  62.09  53.16  10.71
# 257        10.52     68.19  ...  15.06  7.67     56.31  61.49  52.62  10.51
# 258        10.40     68.19  ...  15.67  7.35     56.29  61.30  53.55  11.39
# 259        10.56     69.89  ...  15.91  7.48     55.50  63.84  56.66  11.42
#
#      TLEVISACPO.MX   VALE  WEGE3.SA   WMT.MX
# 0            29.73  13.79     37.72  2710.05
# 1            30.29  14.12     37.27  2682.86
# 2            30.36  14.07     37.24  2690.68
# 3            30.13  13.77     35.42  2693.07
# 4            30.41  14.60     35.32  2750.13
# ..             ...    ...       ...      ...
# 255          40.84  15.26     28.95  2821.61
# 256          41.67  15.92     28.96  2762.68
# 257          40.34  16.01     28.05  2731.72
# 258          40.22  15.82     28.76  2765.64
# 259          41.65  16.52     28.83  2767.68
#
# [260 rows x 36 columns]

# %% [markdown]
# **Evaluacion de la calidad de la imputacion**

# %%
#Tecnica: Error cuadratico medio MSE en escenario 1
datos_reales = np.array(data1)
datos_imputados = np.array(imputed_data1)
# Identificar y eliminar los elementos NaN en los datos reales y los datos imputados
mask = ~np.isnan(datos_reales)
datos_reales = datos_reales[mask]
datos_imputados = datos_imputados[mask]
# Calcular el MSE para los datos restantes
mse1 = mean_squared_error(datos_reales, datos_imputados)
print("El MSE para los datos imputados es:", round(mse1, 8))
# Out:
# El MSE para los datos imputados es: 7.6e-06

# %%
#Tecnica: Error cuadratico medio MSE en escenario 2
datos_reales = np.array(data2)
datos_imputados = np.array(imputed_data2)
# Identificar y eliminar los elementos NaN en los datos reales y los datos imputados
mask = ~np.isnan(datos_reales)
datos_reales = datos_reales[mask]
datos_imputados = datos_imputados[mask]
# Calcular el MSE para los datos restantes
mse2 = mean_squared_error(datos_reales, datos_imputados)
print("El MSE para los datos imputados es:", round(mse2, 8))
# Out:
# El MSE para los datos imputados es: 7.66e-06

# %%
#Tecnica: Error cuadratico medio MSE en escenario 3
datos_reales = np.array(data3)
datos_imputados = np.array(imputed_data3)
# Identificar y eliminar los elementos NaN en los datos reales y los datos imputados
mask = ~np.isnan(datos_reales)
datos_reales = datos_reales[mask]
datos_imputados = datos_imputados[mask]
# Calcular el MSE para los datos restantes
mse3 = mean_squared_error(datos_reales, datos_imputados)
print("El MSE para los datos imputados es:", round(mse3, 8))
# Out:
# El MSE para los datos imputados es: 7.37e-06

# %%
#Calcular la media de los MSE obtenidos de los tres escenarios
# Crear una lista con los valores del MSE
mse_values = [mse1, mse2, mse3]
# Calcular la media utilizando numpy.mean()
mse_mean = np.mean(mse_values)
# Imprimir el resultado
print("La media de los MSE es:", mse_mean)
# Out:
# La media de los MSE es: 7.541759505622833e-06

# %% [markdown]
# **Revisar si fue correcta la imputacion**

# %%
#Volver a identificar datos faltantes en imputed_data1 posterior a la imputacion por KNN
print("Hay {} datos".format(len(imputed_data1)))
for i in imputed_data1.columns:
    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(imputed_data1[imputed_data1[i].isna()]), np.round(len(imputed_data1[imputed_data1[i].isna()])/len(imputed_data1)*100,2), i))
# Out:
# Hay 260 datos
# Hay 0 (0.0%) datos faltantes en la columna ABEV
# Hay 0 (0.0%) datos faltantes en la columna B3SA3.SA
# Hay 0 (0.0%) datos faltantes en la columna BAP
# Hay 0 (0.0%) datos faltantes en la columna BBAS3.SA
# Hay 0 (0.0%) datos faltantes en la columna BBD
# Hay 0 (0.0%) datos faltantes en la columna BRFS
# Hay 0 (0.0%) datos faltantes en la columna BSAC
# Hay 0 (0.0%) datos faltantes en la columna CCRO3.SA
# Hay 0 (0.0%) datos faltantes en la columna CEMEXCPO.MX
# Hay 0 (0.0%) datos faltantes en la columna CHILE.SN
# Hay 0 (0.0%) datos faltantes en la columna CIB
# Hay 0 (0.0%) datos faltantes en la columna CMPC.SN
# Hay 0 (0.0%) datos faltantes en la columna COPEC.SN
# Hay 0 (0.0%) datos faltantes en la columna EC
# Hay 0 (0.0%) datos faltantes en la columna ENELAM.SN
# Hay 0 (0.0%) datos faltantes en la columna FALABELLA.SN
# Hay 0 (0.0%) datos faltantes en la columna FEMSAUBD.MX
# Hay 0 (0.0%) datos faltantes en la columna FUNO11.MX
# Hay 0 (0.0%) datos faltantes en la columna GFNORTEO.MX
# Hay 0 (0.0%) datos faltantes en la columna GGB
# Hay 0 (0.0%) datos faltantes en la columna GMEXICOB.MX
# Hay 0 (0.0%) datos faltantes en la columna ISA.CL
# Hay 0 (0.0%) datos faltantes en la columna ITSA4.SA
# Hay 0 (0.0%) datos faltantes en la columna ITUB
# Hay 0 (0.0%) datos faltantes en la columna LREN3.SA
# Hay 0 (0.0%) datos faltantes en la columna MGLU3.SA
# Hay 0 (0.0%) datos faltantes en la columna PAGS
# Hay 0 (0.0%) datos faltantes en la columna PBR
# Hay 0 (0.0%) datos faltantes en la columna RENT3.SA
# Hay 0 (0.0%) datos faltantes en la columna SCCO
# Hay 0 (0.0%) datos faltantes en la columna SQM
# Hay 0 (0.0%) datos faltantes en la columna STNE
# Hay 0 (0.0%) datos faltantes en la columna TLEVISACPO.MX
# Hay 0 (0.0%) datos faltantes en la columna VALE
# Hay 0 (0.0%) datos faltantes en la columna WEGE3.SA
# Hay 0 (0.0%) datos faltantes en la columna WMT.MX

# %%
#Volver a identificar datos faltantes en imputed_data2 posterior a la imputacion por KNN
print("Hay {} datos".format(len(imputed_data2)))
for i in imputed_data2.columns:
    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(imputed_data2[imputed_data2[i].isna()]), np.round(len(imputed_data2[imputed_data2[i].isna()])/len(imputed_data2)*100,2), i))
# Out:
# Hay 260 datos
# Hay 0 (0.0%) datos faltantes en la columna ABEV
# Hay 0 (0.0%) datos faltantes en la columna B3SA3.SA
# Hay 0 (0.0%) datos faltantes en la columna BAP
# Hay 0 (0.0%) datos faltantes en la columna BBAS3.SA
# Hay 0 (0.0%) datos faltantes en la columna BBD
# Hay 0 (0.0%) datos faltantes en la columna BRFS
# Hay 0 (0.0%) datos faltantes en la columna BSAC
# Hay 0 (0.0%) datos faltantes en la columna CCRO3.SA
# Hay 0 (0.0%) datos faltantes en la columna CEMEXCPO.MX
# Hay 0 (0.0%) datos faltantes en la columna CHILE.SN
# Hay 0 (0.0%) datos faltantes en la columna CIB
# Hay 0 (0.0%) datos faltantes en la columna CMPC.SN
# Hay 0 (0.0%) datos faltantes en la columna COPEC.SN
# Hay 0 (0.0%) datos faltantes en la columna EC
# Hay 0 (0.0%) datos faltantes en la columna ENELAM.SN
# Hay 0 (0.0%) datos faltantes en la columna FALABELLA.SN
# Hay 0 (0.0%) datos faltantes en la columna FEMSAUBD.MX
# Hay 0 (0.0%) datos faltantes en la columna FUNO11.MX
# Hay 0 (0.0%) datos faltantes en la columna GFNORTEO.MX
# Hay 0 (0.0%) datos faltantes en la columna GGB
# Hay 0 (0.0%) datos faltantes en la columna GMEXICOB.MX
# Hay 0 (0.0%) datos faltantes en la columna ISA.CL
# Hay 0 (0.0%) datos faltantes en la columna ITSA4.SA
# Hay 0 (0.0%) datos faltantes en la columna ITUB
# Hay 0 (0.0%) datos faltantes en la columna LREN3.SA
# Hay 0 (0.0%) datos faltantes en la columna MGLU3.SA
# Hay 0 (0.0%) datos faltantes en la columna PAGS
# Hay 0 (0.0%) datos faltantes en la columna PBR
# Hay 0 (0.0%) datos faltantes en la columna RENT3.SA
# Hay 0 (0.0%) datos faltantes en la columna SCCO
# Hay 0 (0.0%) datos faltantes en la columna SQM
# Hay 0 (0.0%) datos faltantes en la columna STNE
# Hay 0 (0.0%) datos faltantes en la columna TLEVISACPO.MX
# Hay 0 (0.0%) datos faltantes en la columna VALE
# Hay 0 (0.0%) datos faltantes en la columna WEGE3.SA
# Hay 0 (0.0%) datos faltantes en la columna WMT.MX

# %%
#Volver a identificar datos faltantes en matrix3 posterior a la imputacion por KNN
print("Hay {} datos".format(len(imputed_data3)))
for i in imputed_data3.columns:
    print("Hay {} ({}%) datos faltantes en la columna {}".format(len(imputed_data3[imputed_data3[i].isna()]), np.round(len(imputed_data3[imputed_data3[i].isna()])/len(imputed_data3)*100,2), i))
# Out:
# Hay 260 datos
# Hay 0 (0.0%) datos faltantes en la columna ABEV
# Hay 0 (0.0%) datos faltantes en la columna B3SA3.SA
# Hay 0 (0.0%) datos faltantes en la columna BAP
# Hay 0 (0.0%) datos faltantes en la columna BBAS3.SA
# Hay 0 (0.0%) datos faltantes en la columna BBD
# Hay 0 (0.0%) datos faltantes en la columna BRFS
# Hay 0 (0.0%) datos faltantes en la columna BSAC
# Hay 0 (0.0%) datos faltantes en la columna CCRO3.SA
# Hay 0 (0.0%) datos faltantes en la columna CEMEXCPO.MX
# Hay 0 (0.0%) datos faltantes en la columna CHILE.SN
# Hay 0 (0.0%) datos faltantes en la columna CIB
# Hay 0 (0.0%) datos faltantes en la columna CMPC.SN
# Hay 0 (0.0%) datos faltantes en la columna COPEC.SN
# Hay 0 (0.0%) datos faltantes en la columna EC
# Hay 0 (0.0%) datos faltantes en la columna ENELAM.SN
# Hay 0 (0.0%) datos faltantes en la columna FALABELLA.SN
# Hay 0 (0.0%) datos faltantes en la columna FEMSAUBD.MX
# Hay 0 (0.0%) datos faltantes en la columna FUNO11.MX
# Hay 0 (0.0%) datos faltantes en la columna GFNORTEO.MX
# Hay 0 (0.0%) datos faltantes en la columna GGB
# Hay 0 (0.0%) datos faltantes en la columna GMEXICOB.MX
# Hay 0 (0.0%) datos faltantes en la columna ISA.CL
# Hay 0 (0.0%) datos faltantes en la columna ITSA4.SA
# Hay 0 (0.0%) datos faltantes en la columna ITUB
# Hay 0 (0.0%) datos faltantes en la columna LREN3.SA
# Hay 0 (0.0%) datos faltantes en la columna MGLU3.SA
# Hay 0 (0.0%) datos faltantes en la columna PAGS
# Hay 0 (0.0%) datos faltantes en la columna PBR
# Hay 0 (0.0%) datos faltantes en la columna RENT3.SA
# Hay 0 (0.0%) datos faltantes en la columna SCCO
# Hay 0 (0.0%) datos faltantes en la columna SQM
# Hay 0 (0.0%) datos faltantes en la columna STNE
# Hay 0 (0.0%) datos faltantes en la columna TLEVISACPO.MX
# Hay 0 (0.0%) datos faltantes en la columna VALE
# Hay 0 (0.0%) datos faltantes en la columna WEGE3.SA
# Hay 0 (0.0%) datos faltantes en la columna WMT.MX

# %% [markdown]
# **Outliers**

# %%
#Identificar Outliers en imputed_data 1,2 y 3
plt.figure(figsize=(22,15))
plt.subplot(311)
imputed_data1.boxplot(grid=True,fontsize=5 )
plt.subplot(312)
imputed_data2.boxplot(grid=True,fontsize=5)
plt.subplot(313)
imputed_data3.boxplot(grid=True,fontsize=5)
plt.legend(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Funcion para Contar y reemplazar outliers con el metodo IQR en imputed_data 1,2 y 3
def eliminar_outliers(df):
    # Calcular los límites para identificar outliers
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Identificar y contar los outliers en cada columna
    outliers_count = (df < lower_bound) | (df > upper_bound)
    outliers_count = pd.DataFrame(outliers_count)  # Convertir a DataFrame

    # Eliminar los outliers del DataFrame
    df_sin_outliers = df[~outliers_count.any(axis=1)]

    return df_sin_outliers, outliers_count


def aplicar_eliminar_outliers(dataframes):
    resultados = {}

    for nombre, df in dataframes.items():
        df_sin_outliers, _ = eliminar_outliers(df)

        # Guardar el DataFrame sin outliers en el diccionario
        resultados[nombre] = df_sin_outliers

    return resultados

# %%
#Aplicando la funcion en imputed_data 1, 2 y 3

# Crear un diccionario con los nombres de los DataFrames y los DataFrames correspondientes
dataframes = {
    'imputed_data1': imputed_data1,
    'imputed_data2': imputed_data2,
    'imputed_data3': imputed_data3
}

# Aplicar la función eliminar_outliers a los DataFrames y obtener los resultados
resultados = aplicar_eliminar_outliers(dataframes)

# Resultados individuales
for nombre, df_sin_outliers in resultados.items():
    print(f"Resultados para {nombre}:")
    print("DataFrame sin outliers:")
    print(df_sin_outliers)
    print()
# Out:
# Resultados para imputed_data1:
# DataFrame sin outliers:
#      ABEV  B3SA3.SA     BAP  BBAS3.SA   BBD  BRFS   BSAC  CCRO3.SA  \
# 13   3.89      9.53  246.13     39.27  7.85  6.18  23.79     10.85
# 14   3.85      9.37  242.32     38.45  7.56  6.05  23.60     10.76
# 15   3.69      9.11  239.51     36.35  7.11  5.75  22.71     10.23
# 16   3.68      9.09  237.97     36.61  7.20  5.73  22.68     10.23
# 17   3.78      9.32  238.86     37.48  7.25  5.84  22.77     10.28
# ..    ...       ...     ...       ...   ...   ...    ...       ...
# 241  3.65     14.43  207.18     38.64  6.63  7.43  16.91     16.99
# 244  3.44     14.03  201.39     39.25  6.66  7.41  16.79     16.39
# 9            34.41  14.50     34.41  2780.97
# 18           38.13  13.44     34.37  2771.10
# 23           47.19  14.09     36.32  2779.02
# 24           42.68  14.87     35.42  2913.58
# 25           35.82  15.04     37.21  2834.98
# ..             ...    ...       ...      ...
# 221          37.85  12.56     31.03  2921.49
# 222          38.62  12.66     29.40  2970.43
# 223          39.06  12.98     29.39  2956.44
# 226          40.01  14.12     28.29  2936.48
# 231          41.71  14.37     29.75  2900.52
#
# [164 rows x 36 columns]

# %%
dataclean1 = resultados['imputed_data1']
dataclean2 = resultados['imputed_data2']
dataclean3 = resultados['imputed_data3']

# %% [markdown]
# Validacion de eliminacion de outliers (por definir)

# %% [markdown]
# **Prueba de no estacionariedad**

# %%
#Hipótesis nula: La serie de tiempo es no estacionaria (Pvalue > 0,05)
#Hipótesis alternativa: La serie de tiempo es estacionaria (Pvalue < 0,05)

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
#Calcular rendimientos logaritmicos para normalizar los datos en una misma escala
log_rtn1 =np.log(dataclean1/dataclean1.shift(1))
#Eliminando NaN generados en primera linea por calculo de Log_rtn
log_rtn1 = log_rtn1.dropna()
log_rtn1
# Out:
#          ABEV  B3SA3.SA       BAP  BBAS3.SA       BBD      BRFS      BSAC  \
# 14  -0.010336 -0.016932 -0.015601 -0.021102 -0.037642 -0.021260 -0.008019
# 15  -0.042447 -0.028140 -0.011664 -0.056164 -0.061369 -0.050858 -0.038441
# 16  -0.002714 -0.002198 -0.006451  0.007127  0.012579 -0.003484 -0.001322
# 17   0.026811  0.024988  0.003733  0.023486  0.006920  0.019015  0.003960
# 18  -0.043250 -0.057411 -0.006215 -0.057096 -0.053837 -0.043752 -0.007937
# ..        ...       ...       ...       ...       ...       ...       ...
# 241 -0.008186  0.038140  0.010920  0.004929  0.015198  0.044024  0.047844
# 244 -0.059256 -0.028111 -0.028345  0.015663  0.004515 -0.002695 -0.007122
# 245  0.002903 -0.007871 -0.008677  0.001019  0.002999 -0.016327 -0.022283
# 246 -0.023461  0.006445  0.015950 -0.009719  0.004481 -0.022192 -0.005496
# 247  0.000000  0.005694  0.001625  0.043994  0.005944  0.001402 -0.009228
#
#      CCRO3.SA  CEMEXCPO.MX  CHILE.SN  ...      PAGS       PBR  RENT3.SA  \
# 14  -0.008330    -0.007680  0.010539  ...  0.022672 -0.034368 -0.013710
# 15  -0.050511    -0.062485  0.001022  ... -0.039429 -0.074000 -0.027998
# 16   0.000000     0.042462 -0.010657  ... -0.023249  0.003008  0.004491
# 17   0.004876    -0.014714  0.005664  ...  0.050255  0.032499  0.007555
# 18  -0.038676     0.022549 -0.006051  ...  0.006884 -0.056816 -0.035519
# ..        ...          ...       ...  ...       ...       ...       ...
# 241  0.011841    -0.006609  0.017737  ...  0.026125  0.006667  0.015380
# 244 -0.035954     0.027471 -0.017574  ... -0.001801  0.029462 -0.011464
# 245 -0.029724     0.005148  0.032170  ... -0.031429 -0.003231 -0.016950
# 246 -0.001258    -0.006439 -0.019563  ...  0.005872 -0.013030 -0.011595
# 247  0.039487     0.039270  0.008636  ...  0.022548  0.029081  0.033419
#
#          SCCO       SQM      STNE  TLEVISACPO.MX      VALE  WEGE3.SA    WMT.MX
# 14   0.008135  0.009390  0.127728       0.005783 -0.003029 -0.010210 -0.003782
# 15  -0.048198 -0.030429 -0.026662      -0.027448 -0.048689 -0.018412  0.009649
# 16   0.009115 -0.001330 -0.033555      -0.008539  0.003180 -0.006993 -0.005330
# 17   0.031263 -0.010366  0.074320       0.008797  0.012618 -0.002342  0.002535
# 18  -0.007250 -0.007761 -0.050134       0.042613 -0.027544 -0.032165 -0.003609
# ..        ...       ...       ...            ...       ...       ...       ...
# 241  0.013780  0.018852  0.041926      -0.000247  0.014582  0.031898  0.019716
# 244  0.035745  0.056522 -0.085447      -0.038568  0.040376  0.051653 -0.020589
# 245 -0.024303 -0.027655 -0.019668      -0.008258 -0.029302 -0.041413  0.007802
# 246 -0.007717 -0.011614 -0.018063      -0.003114 -0.037020  0.010641 -0.009879
# 247  0.015375  0.038065  0.003490       0.037750  0.027059  0.035647 -0.007184
#
# [215 rows x 36 columns]

# %%
# Convertir la serie de tiempo en un array unidimensional
# Crear una lista para almacenar los resultados de la prueba ADF para cada columna
adf_results = []
adf_results
# Out:
# []

# %%
# Realizar la prueba ADF para cada columna y almacenar los resultados en la lista
for col in log_rtn1.columns:
    result = adfuller(log_rtn1[col])
    adf_results.append(result[1])

# %%
# Calcular el promedio de los resultados de la prueba ADF para cada columna
mean_pvalues = sum(adf_results) / len(adf_results)
mean_pvalues
# Out:
# 0.001355291931698939

# %%
# Imprimir el resultado
if mean_pvalues < 0.05:
    print("Se rechaza la hipótesis nula: La serie de tiempo es estacionaria.")
else:
    print("No se puede rechazar la hipótesis nula:  La serie de tiempo es no estacionaria.")
# Out:
# Se rechaza la hipótesis nula: La serie de tiempo es estacionaria.

# %% [markdown]
# **Calculo de Correlaciones lineales (Pearson)**

# %%
#Calcular matrices de coeficientes de correlacion lineal (Pearson)
Coefcorr1 = dataclean1.corr()
Coefcorr2 = dataclean2.corr()
Coefcorr3 = dataclean3.corr()

# %%
#Graficar matrices de correlaciones lineales
plt.figure(figsize=(40, 30))
plt.subplot(131)
sns.heatmap(Coefcorr1, annot=False, annot_kws = {'size':4}, vmax=1, vmin=-1, fmt=',.1f', cmap='Spectral', linewidth=.1, cbar_kws={'shrink': 0.317}, square=True)
plt.subplot(132)
sns.heatmap(Coefcorr2, annot=False, annot_kws = {'size':4}, vmax=1, vmin=-1, fmt=',.1f', cmap='Spectral', linewidth=.1, cbar_kws={'shrink': 0.317}, square=True)
plt.subplot(133)
sns.heatmap(Coefcorr3, annot=False, annot_kws = {'size':4}, vmax=1, vmin=-1, fmt=',.1f', cmap='Spectral', linewidth=.1, cbar_kws={'shrink': 0.317}, square=True)
# Out:
# <Axes: >

# %% [markdown]
# **Cluster**

# %%
from sklearn.preprocessing import StandardScaler
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#Etadisticos descriptivos
dataclean1.describe()
# Out:
#              ABEV    B3SA3.SA         BAP    BBAS3.SA         BBD        BRFS  \
# count  216.000000  216.000000  216.000000  216.000000  216.000000  216.000000
# BSAC                0.514496  0.999215  0.213006  0.812549
# CCRO3.SA            0.642386  0.973914  0.257070  0.284361
# CEMEXCPO.MX         0.996969  0.848575  0.852129  0.536149
# CHILE.SN            0.526347  0.938822  0.257077  0.909561
# CIB                 0.603820  0.806282  0.563425  0.913412
# CMPC.SN             0.923277  0.717947  0.974736  0.522573
# COPEC.SN            0.984612  0.777877  0.904204  0.442239
# EC                  0.634598  0.461810  0.803290  0.969539
# ENELAM.SN           0.337080  0.992220  0.216375  0.607227
# FALABELLA.SN        0.663313  0.988530  0.201440  0.460399
# FEMSAUBD.MX         0.889834  0.943076  0.897108  0.919291
# FUNO11.MX           0.351274  0.976199  0.349466  0.590336
# GFNORTEO.MX         0.947332  0.915904  0.928514  0.999366
# GGB                 0.680675  0.544703  0.491502  0.999972
# GMEXICOB.MX         0.603898  0.677435  0.848778  0.969295
# ISA.CL              0.791647  0.999960  0.543017  0.306072
# ITSA4.SA            0.601437  0.999483  0.434646  0.337302
# ITUB                0.997515  0.702818  0.998541  0.980317
# LREN3.SA            0.750552  0.997928  0.190100  0.408929
# MGLU3.SA            0.558214  0.983814  0.123359  0.448331
# PAGS                0.866137  0.845604  0.998775  0.721836
# PBR                 0.867330  0.425100  0.992645  0.990231
# RENT3.SA            0.865996  0.995126  0.225242  0.516150
# SCCO                0.559967  0.453400  0.696835  0.999990
# SQM                 0.991055  0.711079  0.800259  0.254101
# STNE                0.487977  0.974505  0.424579  0.838431
# TLEVISACPO.MX       0.000000  0.977456  0.574498  0.888774
# VALE                0.977456  0.000000  0.992169  0.866739
# WEGE3.SA            0.574498  0.992169  0.000000  0.687632
# WMT.MX              0.888774  0.866739  0.687632  0.000000
#
# [36 rows x 36 columns]

# %%
# Realizamos el Clustering Jerárquico
linkagematrix1 = shc.linkage(distmatrix1, method='ward')
linkagematrix2 = shc.linkage(distmatrix2, method='ward')
linkagematrix3 = shc.linkage(distmatrix3, method='ward')

# %%
# Visualizamos los dendrogramas
plt.figure(figsize=(20, 10))
plt.title("Dendogramas")
plt.subplot(131)
dendrogram1 = shc.dendrogram(linkagematrix1, labels=Coefcorr1.columns)
plt.title("Escenario 1")
plt.xlabel("Tickets")
plt.ylabel("Distancia")
plt.subplot(132)
dendrogram2 = shc.dendrogram(linkagematrix2, labels=Coefcorr2.columns)
plt.title("Escenario 2")
plt.xlabel("Tickets")
plt.ylabel("Distancia")
plt.subplot(133)
dendrogram3 = shc.dendrogram(linkagematrix3, labels=Coefcorr3.columns)
plt.title("Escenario 3")
plt.xlabel("Tickets")
plt.ylabel("Distancia")
# Out:
# Text(0, 0.5, 'Distancia')

# %%
# Ordenamos los datos según el Clustering Jerárquico
order = dendrogram1['leaves']
ordered_df = Coefcorr1.iloc[:, order]

# %%
# Visualizamos la matriz de correlación reordenada
plt.figure(figsize=(12, 12))
sns.heatmap(ordered_df.corr(), annot=False, annot_kws = {'size':4}, vmax=1, vmin=-1, fmt=',.1f', cmap='Spectral', linewidth=.1, cbar_kws={'shrink': 0.317}, square=True)
plt.title("Matriz de Correlación Reordenada")
plt.show()
